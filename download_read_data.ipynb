# %%
import os
import gzip
import time
import shutil
import ftplib
import datetime
import numpy as np
import pandas as pd
from tqdm import tqdm
from matplotlib import pyplot as plt

# %% [markdown]
# # Downloading the data
# <br>
# Here I download the data from ftp.ncdc.noaa.gov/pub/data/swdi/stormevents/csvfiles/ <br>
# to "input_dir_name" directory and unzipping the downloaded files to "output_dir_name" directory <br>
# <br>

# %%
input_dir_name = '/home/avartation/Desktop/data'
output_dir_name = '/home/avartation/Desktop/csv_data'

# %%
############################
##    Downloading data    ##
############################

ftp = ftplib.FTP('ftp.ncdc.noaa.gov')
ftp.login('anonymous', 'email@email.com')
ftp.cwd('/pub/data/swdi/stormevents/csvfiles/')

for file_name in ftp.nlst():
    time.sleep(1)
    if file_name[-3:]=='.gz':
        print(file_name)
        file = open(os.path.join(input_dir_name, file_name), 'wb')
        ftp.retrbinary('RETR '+file_name, file.write)
        file.close()

print('\n\n\n Done ! \n\n\n')
# Out:
# StormEvents_details-ftp_v1.0_d2012_c20170519.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2012_c20170519.csv.gz
# StormEvents_locations-ftp_v1.0_d2012_c20170519.csv.gz
# StormEvents_locations-ftp_v1.0_d1969_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1972_c20181029.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1980_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1992_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1950_c20170120.csv.gz
# StormEvents_locations-ftp_v1.0_d2007_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1952_c20170619.csv.gz
# StormEvents_locations-ftp_v1.0_d1953_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1954_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1955_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1956_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1957_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1959_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1961_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1963_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1964_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1965_c20190301.csv.gz
# StormEvents_locations-ftp_v1.0_d1966_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1967_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1969_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1971_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1972_c20181029.csv.gz
# StormEvents_locations-ftp_v1.0_d1973_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1974_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1975_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1976_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1982_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1983_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1984_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1987_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1988_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1990_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1994_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1996_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1995_c20170522.csv.gz
# StormEvents_details-ftp_v1.0_d1997_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1998_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2001_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2001_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2004_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2007_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1951_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2009_c20180718.csv.gz
# StormEvents_details-ftp_v1.0_d1955_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1960_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1961_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1962_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1963_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1964_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1970_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1975_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1979_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1981_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1982_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1991_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1992_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1992_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1995_c20170522.csv.gz
# StormEvents_details-ftp_v1.0_d1999_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2003_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2004_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2005_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d2005_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1976_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1977_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1979_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1982_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1983_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1985_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1986_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1987_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1989_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1990_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1996_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1998_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1969_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d2008_c20180718.csv.gz
# StormEvents_locations-ftp_v1.0_d2009_c20180718.csv.gz
# StormEvents_details-ftp_v1.0_d2018_c20190325.csv.gz
# StormEvents_locations-ftp_v1.0_d2018_c20190325.csv.gz
# StormEvents_details-ftp_v1.0_d2017_c20190405.csv.gz
# StormEvents_locations-ftp_v1.0_d2013_c20170519.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2010_c20170726.csv.gz
# StormEvents_locations-ftp_v1.0_d2015_c20180525.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2016_c20180718.csv.gz
# StormEvents_locations-ftp_v1.0_d2017_c20190405.csv.gz
# StormEvents_details-ftp_v1.0_d2014_c20180718.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2017_c20190405.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1961_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1962_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1965_c20190301.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1967_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1968_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1971_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1973_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1975_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1953_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1954_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1956_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1957_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1958_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1959_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1965_c20190301.csv.gz
# StormEvents_details-ftp_v1.0_d1966_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1967_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1968_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2000_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1971_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1988_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1973_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1974_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1976_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1977_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1978_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1984_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1983_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1985_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1986_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1987_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1988_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1990_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1993_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1994_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1999_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2000_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d2003_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1951_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1953_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1954_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1955_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1956_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1957_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1958_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1959_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1960_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1963_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1964_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1966_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1994_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1970_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1972_c20181029.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1974_c20160223.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1978_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1980_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1981_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1984_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1989_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1991_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1993_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1995_c20170522.csv.gz
# StormEvents_locations-ftp_v1.0_d1997_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1998_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d2001_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d2004_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2005_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2007_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2013_c20170519.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2013_c20170519.csv.gz
# StormEvents_details-ftp_v1.0_d2010_c20170726.csv.gz
# StormEvents_locations-ftp_v1.0_d2010_c20170726.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2015_c20180525.csv.gz
# StormEvents_details-ftp_v1.0_d2016_c20180718.csv.gz
# StormEvents_locations-ftp_v1.0_d2016_c20180718.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2018_c20190325.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1997_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1952_c20170619.csv.gz
# StormEvents_locations-ftp_v1.0_d1952_c20170619.csv.gz
# StormEvents_locations-ftp_v1.0_d2000_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2002_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d2002_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1951_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1958_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1960_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1962_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1968_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1970_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1977_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1978_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1979_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1980_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1981_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1985_c20160223.csv.gz
# StormEvents_locations-ftp_v1.0_d1986_c20160223.csv.gz
# StormEvents_details-ftp_v1.0_d1989_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1991_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1993_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d1996_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1999_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2002_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2003_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2006_c20170717.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2006_c20170717.csv.gz
# StormEvents_locations-ftp_v1.0_d2006_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2015_c20180525.csv.gz
# StormEvents_details-ftp_v1.0_d2009_c20180718.csv.gz
# StormEvents_details-ftp_v1.0_d2011_c20180718.csv.gz
# StormEvents_details-ftp_v1.0_d2008_c20180718.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2008_c20180718.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2011_c20180718.csv.gz
# StormEvents_locations-ftp_v1.0_d2011_c20180718.csv.gz
# StormEvents_fatalities-ftp_v1.0_d2014_c20180718.csv.gz
# StormEvents_locations-ftp_v1.0_d2014_c20180718.csv.gz
# StormEvents_fatalities-ftp_v1.0_d1950_c20170120.csv.gz
# StormEvents_details-ftp_v1.0_d1950_c20170120.csv.gz
#
#
#
#  Done !

# %%
###############################
##    Unzipping the files    ##
###############################

file_count = len(os.listdir(input_dir_name))

for i, file_name in enumerate(os.listdir(input_dir_name)):
    print('{}-th out of {} files is being processed ({})'.format(i+1, file_count, file_name))
    assert file_name[-3:]=='.gz', '\n\n Foreign file format encountered !!! \n\n'
    with gzip.open(os.path.join(input_dir_name, file_name), 'rb') as file_in:
        with open(os.path.join(output_dir_name, file_name[:-3]), 'wb') as file_out:
            shutil.copyfileobj(file_in, file_out)

print('\n\n\n Done ! \n\n\n')

# %% [markdown]
# # Reading the data
# <br>
# So we now have 3 files per year <br> <br>
# <hr>
# <h4>StormEvents_details-ftp_v1.0_dYYYY_cYYYYMMDD.csv</h4> <br>
# <h4>StormEvents_locations-ftp_v1.0_dYYYY_cYYYYMMDD.csv</h4> <br>
# <h4>StormEvents_fatalities-ftp_v1.0_dYYYY_cYYYYMMDD.csv</h4>
# <hr> <br>
# The main information we need is in StormEvents_details-ftp_v1.0_dYYYY_cYYYYMMDD.csv file <br>
# <br>
# Here they are read. <br>
# <br>

# %%
########################
##    Reading data    ##
########################

data = {}
details = 0
locations = 0
fatalities = 0
else_count = 0

file_count = len(os.listdir(output_dir_name))

for i, file_name in enumerate(os.listdir(output_dir_name)):
    print('{}-th out of {} files is being processed ({})'.format(i+1, file_count, file_name))
    assert file_name[-4:]=='.csv', '\n\n Foreign file format encountered !!! \n\n'
    assert file_name[:11]=='StormEvents', '\n\n Foreign file name encountered !!! \n\n'
    
    year = file_name[-18:-14]
    if year not in data:
        data[year] = {}
    
    if file_name[12:19]=='details':
        data[year]['details'] = pd.read_csv(os.path.join(output_dir_name, file_name))
        details += 1
    elif file_name[12:21]=='locations':
        data[year]['locations'] = pd.read_csv(os.path.join(output_dir_name, file_name))
        locations += 1
    elif file_name[12:22]=='fatalities':
        data[year]['fatalities'] = pd.read_csv(os.path.join(output_dir_name, file_name))
        fatalities += 1
    else:
        raise Exception('\n\n Foreign file encountered !!! \n\n')

print('\n\n       Done ! \n')
print('details    :', details)
print('locations  :', locations)
print('fatalities :', fatalities)
print('else_count :', else_count)
# Out:
# 1-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1973_c20160223.csv)
# 2-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1972_c20181029.csv)
# 3-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1971_c20160223.csv)
# 4-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2001_c20170717.csv)
# 5-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1994_c20170717.csv)
# 6-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1977_c20160223.csv)
# 7-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1974_c20160223.csv)
# 8-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1996_c20170717.csv)
# /home/avartation/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 9-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1968_c20160223.csv)
# 10-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2017_c20190405.csv)
# 11-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1989_c20170717.csv)
# 12-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2009_c20180718.csv)
# 13-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1999_c20170717.csv)
# 14-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1956_c20170717.csv)
# 15-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2004_c20170717.csv)
# 16-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2003_c20170717.csv)
# 17-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1964_c20160223.csv)
# 18-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1982_c20160223.csv)
# 19-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2015_c20180525.csv)
# 20-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1969_c20170717.csv)
# 21-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1952_c20170619.csv)
# 22-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1966_c20160223.csv)
# 23-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1986_c20160223.csv)
# 24-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1986_c20160223.csv)
# 25-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1956_c20170717.csv)
# 26-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2014_c20180718.csv)
# 27-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1986_c20160223.csv)
# 28-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1968_c20160223.csv)
# 29-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1996_c20170717.csv)
# 30-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1954_c20160223.csv)
# 31-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1995_c20170522.csv)
# 32-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1960_c20160223.csv)
# 33-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1980_c20170717.csv)
# 34-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2017_c20190405.csv)
# 35-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1991_c20170717.csv)
# 36-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1981_c20170717.csv)
# 37-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2016_c20180718.csv)
# 38-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2004_c20170717.csv)
# 39-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1988_c20170717.csv)
# 40-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1997_c20170717.csv)
# /home/avartation/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 41-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1987_c20160223.csv)
# 42-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2010_c20170726.csv)
# 43-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1951_c20160223.csv)
# 44-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1965_c20190301.csv)
# 45-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2012_c20170519.csv)
# 46-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1993_c20170717.csv)
# 47-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1962_c20160223.csv)
# 48-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1971_c20160223.csv)
# 49-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1989_c20170717.csv)
# 50-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2010_c20170726.csv)
# 51-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1992_c20170717.csv)
# 52-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1990_c20170717.csv)
# 53-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1985_c20160223.csv)
# 54-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2002_c20170717.csv)
# 55-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1954_c20160223.csv)
# 56-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2000_c20170717.csv)
# 57-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1975_c20160223.csv)
# 58-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1961_c20160223.csv)
# 59-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1992_c20170717.csv)
# 60-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1951_c20160223.csv)
# 61-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1972_c20181029.csv)
# 62-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2006_c20170717.csv)
# 63-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1989_c20170717.csv)
# 64-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1979_c20160223.csv)
# 65-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2013_c20170519.csv)
# 66-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1957_c20160223.csv)
# 67-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1959_c20160223.csv)
# 68-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1970_c20160223.csv)
# 69-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1978_c20160223.csv)
# 70-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1964_c20160223.csv)
# 71-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2014_c20180718.csv)
# 72-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2000_c20170717.csv)
# 73-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1964_c20160223.csv)
# 74-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2006_c20170717.csv)
# 75-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1988_c20170717.csv)
# 76-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1953_c20160223.csv)
# 77-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1968_c20160223.csv)
# 78-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1970_c20160223.csv)
# 79-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2007_c20170717.csv)
# 80-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1952_c20170619.csv)
# 81-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1960_c20160223.csv)
# 82-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1977_c20160223.csv)
# 83-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2013_c20170519.csv)
# 84-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1993_c20170717.csv)
# 85-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2002_c20170717.csv)
# 86-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1979_c20160223.csv)
# 87-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2009_c20180718.csv)
# 88-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1962_c20160223.csv)
# 89-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1961_c20160223.csv)
# 90-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1950_c20170120.csv)
# 91-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1970_c20160223.csv)
# 92-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1958_c20160223.csv)
# 93-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1991_c20170717.csv)
# 94-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1974_c20160223.csv)
# 95-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2001_c20170717.csv)
# 96-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2008_c20180718.csv)
# 97-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1965_c20190301.csv)
# 98-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1969_c20170717.csv)
# 99-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1981_c20170717.csv)
# 100-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1957_c20160223.csv)
# 101-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1953_c20160223.csv)
# 102-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2008_c20180718.csv)
# 103-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2002_c20170717.csv)
# 104-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2005_c20170717.csv)
# 105-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1973_c20160223.csv)
# 106-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2015_c20180525.csv)
# 107-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2012_c20170519.csv)
# 108-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1976_c20160223.csv)
# 109-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2001_c20170717.csv)
# 110-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1998_c20170717.csv)
# 111-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2008_c20180718.csv)
# 112-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1997_c20170717.csv)
# 113-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1975_c20160223.csv)
# 114-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1999_c20170717.csv)
# 115-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1978_c20160223.csv)
# 116-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2013_c20170519.csv)
# 117-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1974_c20160223.csv)
# 118-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1962_c20160223.csv)
# 119-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1984_c20170717.csv)
# 120-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2014_c20180718.csv)
# 121-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1997_c20170717.csv)
# 122-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1963_c20160223.csv)
# 123-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2011_c20180718.csv)
# 124-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1955_c20160223.csv)
# 125-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1979_c20160223.csv)
# 126-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2010_c20170726.csv)
# 127-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1958_c20160223.csv)
# 128-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1951_c20160223.csv)
# 129-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2018_c20190325.csv)
# 130-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1977_c20160223.csv)
# 131-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2016_c20180718.csv)
# 132-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1955_c20160223.csv)
# 133-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1955_c20160223.csv)
# 134-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1998_c20170717.csv)
# 135-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1976_c20160223.csv)
# 136-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1990_c20170717.csv)
# 137-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1983_c20160223.csv)
# 138-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1971_c20160223.csv)
# 139-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1953_c20160223.csv)
# 140-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2003_c20170717.csv)
# 141-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2009_c20180718.csv)
# 142-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1950_c20170120.csv)
# 143-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1961_c20160223.csv)
# 144-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1978_c20160223.csv)
# 145-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2003_c20170717.csv)
# 146-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1990_c20170717.csv)
# 147-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1984_c20170717.csv)
# 148-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2018_c20190325.csv)
# 149-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2012_c20170519.csv)
# 150-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1972_c20181029.csv)
# 151-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2017_c20190405.csv)
# 152-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1967_c20160223.csv)
# 153-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1991_c20170717.csv)
# 154-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1967_c20160223.csv)
# 155-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1975_c20160223.csv)
# 156-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1950_c20170120.csv)
# 157-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2004_c20170717.csv)
# 158-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1985_c20160223.csv)
# 159-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2000_c20170717.csv)
# 160-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1958_c20160223.csv)
# 161-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2006_c20170717.csv)
# /home/avartation/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (29,34,35,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 162-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1988_c20170717.csv)
# 163-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1960_c20160223.csv)
# 164-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1956_c20170717.csv)
# 165-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2007_c20170717.csv)
# 166-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2005_c20170717.csv)
# 167-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2005_c20170717.csv)
# 168-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1995_c20170522.csv)
# 169-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1965_c20190301.csv)
# 170-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1969_c20170717.csv)
# 171-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1966_c20160223.csv)
# 172-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1966_c20160223.csv)
# 173-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1959_c20160223.csv)
# 174-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1976_c20160223.csv)
# 175-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1998_c20170717.csv)
# 176-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2011_c20180718.csv)
# 177-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1973_c20160223.csv)
# 178-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2018_c20190325.csv)
# 179-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1982_c20160223.csv)
# 180-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1957_c20160223.csv)
# 181-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1952_c20170619.csv)
# 182-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1954_c20160223.csv)
# 183-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1967_c20160223.csv)
# 184-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1987_c20160223.csv)
# 185-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1983_c20160223.csv)
# 186-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1982_c20160223.csv)
# 187-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1984_c20170717.csv)
# 188-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1963_c20160223.csv)
# 189-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1995_c20170522.csv)
# 190-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1983_c20160223.csv)
# 191-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1963_c20160223.csv)
# 192-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1980_c20170717.csv)
# 193-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1992_c20170717.csv)
# 194-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d1994_c20170717.csv)
# 195-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1994_c20170717.csv)
# 196-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1999_c20170717.csv)
# 197-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1987_c20160223.csv)
# 198-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1993_c20170717.csv)
# 199-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1959_c20160223.csv)
# 200-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d2011_c20180718.csv)
# 201-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2015_c20180525.csv)
# 202-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1981_c20170717.csv)
# 203-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1985_c20160223.csv)
# 204-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d1980_c20170717.csv)
# 205-th out of 207 files is being processed (StormEvents_details-ftp_v1.0_d2016_c20180718.csv)
# 206-th out of 207 files is being processed (StormEvents_locations-ftp_v1.0_d2007_c20170717.csv)
# 207-th out of 207 files is being processed (StormEvents_fatalities-ftp_v1.0_d1996_c20170717.csv)
#
#
#        Done !
#
# details    : 69
# locations  : 69
# fatalities : 69
# else_count : 0

# %% [markdown]
# # BEGIN_LAT and BEGIN_LON
# <br>
# Ok, so the main fearutes, the most important ones are <br> <br>
# <hr>
# <h3>BEGIN_LAT</h3> and <h3>BEGIN_LON</h3>
# <hr> <br>
# As they tell exactly where the event happened. <br>
# But there are rows (events, each row is an event) that don't have this features. <br>
# So firstly I'm cleaning the data from such events by grouping the data year by year. <br>
# <br>

# %%
##############################
##    Year-Location data    ##
##############################

year_loc_data = {}

for year in range(int(min(data.keys())), int(max(data.keys()))+1):
    if str(year) in data:
        print(year, end='   ')
        year_details = data[str(year)]['details']
        if 'BEGIN_LAT' in year_details.columns and 'BEGIN_LON' in year_details.columns:
            year_loc_data[str(year)] = year_details[['BEGIN_LAT', 'BEGIN_LON']].dropna()
            print(year_loc_data[str(year)].shape)
        else:
            raise Exception('\n\n BEGIN_LAT or BEGIN_LON columns not found in data ! \n\n')
    else:
        raise Exception('Year not found in data !')

print('\n\n   Done !  \n\n')
print('year_loc_data :', len(year_loc_data))
# Out:
# 1950   (223, 2)
# 1951   (269, 2)
# 1952   (271, 2)
# 1953   (492, 2)
# 1954   (609, 2)
# 1955   (1413, 2)
# 1956   (1703, 2)
# 1957   (2184, 2)
# 1958   (2213, 2)
# 1959   (1812, 2)
# 1960   (1945, 2)
# 1961   (2246, 2)
# 1962   (2389, 2)
# 1963   (1968, 2)
# 1964   (2348, 2)
# 1965   (2835, 2)
# 1966   (2388, 2)
# 1967   (2688, 2)
# 1968   (3312, 2)
# 1969   (2926, 2)
# 1970   (3215, 2)
# 1971   (3471, 2)
# 1972   (2171, 2)
# 1973   (4453, 2)
# 1974   (5375, 2)
# 1975   (4975, 2)
# 1976   (3767, 2)
# 1977   (3728, 2)
# 1978   (3657, 2)
# 1979   (4278, 2)
# 1980   (6136, 2)
# 1981   (4517, 2)
# 1982   (7126, 2)
# 1983   (8322, 2)
# 1984   (7335, 2)
# 1985   (7979, 2)
# 1986   (8725, 2)
# 1987   (7363, 2)
# 1988   (7257, 2)
# 1989   (10407, 2)
# 1990   (10945, 2)
# 1991   (12516, 2)
# 1992   (13534, 2)
# 1993   (425, 2)
# 1994   (582, 2)
# 1995   (745, 2)
# 1996   (21900, 2)
# 1997   (19597, 2)
# 1998   (27627, 2)
# 1999   (21971, 2)
# 2000   (24590, 2)
# 2001   (25297, 2)
# 2002   (26586, 2)
# 2003   (27440, 2)
# 2004   (26995, 2)
# 2005   (33013, 2)
# 2006   (33825, 2)
# 2007   (35722, 2)
# 2008   (46824, 2)
# 2009   (37573, 2)
# 2010   (38836, 2)
# 2011   (52207, 2)
# 2012   (38086, 2)
# 2013   (35561, 2)
# 2014   (34312, 2)
# 2015   (37287, 2)
# 2016   (36447, 2)
# 2017   (39366, 2)
# 2018   (37893, 2)
#
#
#    Done !
#
#
# year_loc_data : 69

# %%
##################################
##    Merging all years data    ##
##################################

total_data = pd.DataFrame()

for year in tqdm(sorted(year_loc_data.keys())):
    total_data = total_data.append(data[year]['details'].loc[year_loc_data[year].index])

print('\n\n Done ! \n\n')
print(total_data.info())
total_data.head()
# Out:
#  Done !
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 948193 entries, 0 to 61705
# Data columns (total 51 columns):
# BEGIN_YEARMONTH       948193 non-null int64
# BEGIN_DAY             948193 non-null int64
# BEGIN_TIME            948193 non-null int64
# END_YEARMONTH         948193 non-null int64
# END_DAY               948193 non-null int64
# END_TIME              948193 non-null int64
# EPISODE_ID            758958 non-null float64
# EVENT_ID              948193 non-null int64
# STATE                 948193 non-null object
# STATE_FIPS            948193 non-null float64
# YEAR                  948193 non-null int64
# MONTH_NAME            948193 non-null object
# EVENT_TYPE            948193 non-null object
# CZ_TYPE               948193 non-null object
# CZ_FIPS               948193 non-null int64
# CZ_NAME               946636 non-null object
# WFO                   865623 non-null object
# BEGIN_DATE_TIME       948193 non-null object
# CZ_TIMEZONE           948193 non-null object
# END_DATE_TIME         948193 non-null object
# INJURIES_DIRECT       948193 non-null int64
# INJURIES_INDIRECT     948193 non-null int64
# DEATHS_DIRECT         948193 non-null int64
# DEATHS_INDIRECT       948193 non-null int64
# DAMAGE_PROPERTY       688183 non-null object
# DAMAGE_CROPS          617619 non-null object
# SOURCE                705040 non-null object
# MAGNITUDE             774587 non-null float64
# MAGNITUDE_TYPE        282121 non-null object
# FLOOD_CAUSE           76249 non-null object
# CATEGORY              0 non-null float64
# TOR_F_SCALE           66149 non-null object
# TOR_LENGTH            220794 non-null float64
# TOR_WIDTH             220794 non-null float64
# TOR_OTHER_WFO         2073 non-null object
# TOR_OTHER_CZ_STATE    2073 non-null object
# TOR_OTHER_CZ_FIPS     2073 non-null float64
# TOR_OTHER_CZ_NAME     2073 non-null object
# BEGIN_RANGE           775839 non-null float64
# BEGIN_AZIMUTH         587623 non-null object
# BEGIN_LOCATION        759318 non-null object
# END_RANGE             775517 non-null float64
# END_AZIMUTH           586473 non-null object
# END_LOCATION          757990 non-null object
# BEGIN_LAT             948193 non-null float64
# BEGIN_LON             948193 non-null float64
# END_LAT               770704 non-null float64
# END_LON               770704 non-null float64
# EPISODE_NARRATIVE     565505 non-null object
# EVENT_NARRATIVE       483473 non-null object
# DATA_SOURCE           948190 non-null object
# dtypes: float64(13), int64(13), object(25)
# memory usage: 376.2+ MB
# None
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           195004         28        1445         195004       28      1445
# 1           195004         29        1530         195004       29      1530
# 2           195007          5        1800         195007        5      1800
# 3           195007          5        1830         195007        5      1830
# 4           195007         24        1440         195007       24      1440
#
#    EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0         NaN  10096222      OKLAHOMA        40.0  ...        0.0         NaN
# 1         NaN  10120412         TEXAS        48.0  ...        0.0         NaN
# 2         NaN  10104927  PENNSYLVANIA        42.0  ...        0.0         NaN
# 3         NaN  10104928  PENNSYLVANIA        42.0  ...        0.0         NaN
# 4         NaN  10104929  PENNSYLVANIA        42.0  ...        0.0         NaN
#
#   END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT END_LON EPISODE_NARRATIVE  \
# 0          NaN     35.12     -99.20   35.17  -99.20               NaN
# 1          NaN     31.90     -98.60   31.73  -98.60               NaN
# 2          NaN     40.58     -75.70   40.65  -75.47               NaN
# 3          NaN     40.60     -76.75     NaN     NaN               NaN
# 4          NaN     41.63     -79.68     NaN     NaN               NaN
#
#   EVENT_NARRATIVE DATA_SOURCE
# 0             NaN         PUB
# 1             NaN         PUB
# 2             NaN         PUB
# 3             NaN         PUB
# 4             NaN         PUB
#
# [5 rows x 51 columns]

# %% [markdown]
# # Columns that we need
# <br>
# Now we have all the events that have BEGIN_LAT and BEGIN_LON columns(features). <br>
# But surely there ar columns we won't be using while making our models. <br>
# <br>
# So here I filter the total data of all years with the columns necessary for us. <br>
# <br>

# %%
#################################################
##    Filtering data with necessary columns    ##
#################################################

total_data = total_data[['BEGIN_LAT','BEGIN_LON','BEGIN_YEARMONTH','STATE',
                         'INJURIES_DIRECT','INJURIES_INDIRECT','DEATHS_DIRECT',
                         'DEATHS_INDIRECT','DAMAGE_PROPERTY','EVENT_TYPE',
                         'DAMAGE_CROPS','MAGNITUDE','MAGNITUDE_TYPE','FLOOD_CAUSE']]
print(total_data.info())
total_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 948193 entries, 0 to 61705
# Data columns (total 14 columns):
# BEGIN_LAT            948193 non-null float64
# BEGIN_LON            948193 non-null float64
# BEGIN_YEARMONTH      948193 non-null int64
# STATE                948193 non-null object
# INJURIES_DIRECT      948193 non-null int64
# INJURIES_INDIRECT    948193 non-null int64
# DEATHS_DIRECT        948193 non-null int64
# DEATHS_INDIRECT      948193 non-null int64
# DAMAGE_PROPERTY      688183 non-null object
# EVENT_TYPE           948193 non-null object
# DAMAGE_CROPS         617619 non-null object
# MAGNITUDE            774587 non-null float64
# MAGNITUDE_TYPE       282121 non-null object
# FLOOD_CAUSE          76249 non-null object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 128.5+ MB
# None
#    BEGIN_LAT  BEGIN_LON  BEGIN_YEARMONTH         STATE  INJURIES_DIRECT  \
# 0      35.12     -99.20           195004      OKLAHOMA                0
# 1      31.90     -98.60           195004         TEXAS                0
# 2      40.58     -75.70           195007  PENNSYLVANIA                2
# 3      40.60     -76.75           195007  PENNSYLVANIA                0
# 4      41.63     -79.68           195007  PENNSYLVANIA                0
#
#    INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT DAMAGE_PROPERTY  \
# 0                  0              0                0            250K
# 1                  0              0                0             25K
# 2                  0              0                0             25K
# 3                  0              0                0            2.5K
# 4                  0              0                0            2.5K
#
#   EVENT_TYPE DAMAGE_CROPS  MAGNITUDE MAGNITUDE_TYPE FLOOD_CAUSE
# 0    Tornado            0        0.0            NaN         NaN
# 1    Tornado            0        0.0            NaN         NaN
# 2    Tornado            0        0.0            NaN         NaN
# 3    Tornado            0        0.0            NaN         NaN
# 4    Tornado            0        0.0            NaN         NaN

# %%
##############################################
##    Converting BEGIN_YEARMONTH to DATE    ##
##############################################

total_data['DATE'] = total_data.BEGIN_YEARMONTH.apply(lambda date: 
                                                      datetime.date(date//100, 
                                                                    date%100, 
                                                                    np.random.randint(1, 29)))
total_data['DATE'].head()
# Out:
# 0    1950-04-13
# 1    1950-04-22
# 2    1950-07-11
# 3    1950-07-10
# 4    1950-07-18
# Name: DATE, dtype: object

# %%
#######################
##    Saving data    ##
#######################

total_data.to_pickle('total_data.pkl')
