# %%
import keras
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook
# Out:
# Using TensorFlow backend.

# %%
########################
##    Reading data    ##
########################

train_input = np.load('train_input.npy')
train_target = np.load('train_target.npy')

test_input = np.load('test_input.npy')
test_target = np.load('test_target.npy')

print('train_input  :', train_input.shape)
print('train_target :', train_target.shape, end='\n\n')
print('test_input   :', test_input.shape)
print('test_target  :', test_target.shape)
# Out:
# train_input  : (7421, 68, 53, 2)
# train_target : (7421, 68, 53)
#
# test_input   : (797, 68, 53, 2)
# test_target  : (797, 68, 53)

# %%
#########################
##    Reading model    ##
#########################

model = keras.models.load_model('model_1.h5')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         (None, 68, 53, 2)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 7208)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               922752
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_18 (Dense)             (None, 3604)              464916
# _________________________________________________________________
# activation_6 (Activation)    (None, 3604)              0
# _________________________________________________________________
# reshape_6 (Reshape)          (None, 68, 53)            0
# ...
# Total params: 1,404,180
# ...

# %%
#####################################################
##   Evaluating model on train and test datasets   ##
#####################################################

train_loss = model.evaluate(train_input, train_target)
test_loss = model.evaluate(test_input, test_target)

print('\n\nModel loss on train data    :', train_loss)
print('Model loss on test data     :', test_loss, end='\n\n\n')
# Out:
# ...
# 797/797 [==============================] - 0s 174us/step
#
#
# Model loss on train data    : 1.0521801290221653
# Model loss on test data     : 1.0988808055893242

# %%
######################
##    Predicting    ##
######################

pred_train = model.predict(train_input)
pred_test = model.predict(test_input)

# %%
##############################
##    Some train example    ##
##############################

plt.figure(figsize=(20, 5))
plt.plot(train_target[:,3,23])
plt.plot(pred_train[:, 3, 23])
plt.title('Train data')
plt.xlabel('Time')
plt.ylabel('Count_of_events')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
########################
##    Some example    ##
########################

plt.figure(figsize=(20,5))
plt.plot(test_target[:,3,23])
plt.plot(pred_test[:,3,23])
plt.title('Test data')
plt.xlabel('Time')
plt.ylabel('Count_of_events')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">
